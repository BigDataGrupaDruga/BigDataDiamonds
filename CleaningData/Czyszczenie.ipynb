# %%
import pandas as pd
import os

# Link do pliku
url = 'https://raw.githubusercontent.com/BigDataGrupaDruga/BigDataDiamonds/refs/heads/main/CleaningData/daneZtabela.csv'
dataset = pd.read_csv(url)

df = dataset

# %%
df.head()
# Out:
#    #  nr  carat          cut  color  clarity  depth  table  price     x     y  \
# 0  1  "1   0.23    ""Ideal""  ""E""  ""SI2""   61.5   55.0    326  3.95  3.98
# 1  2  "2   0.21  ""Premium""  ""E""  ""SI1""   59.8   61.0    326  3.89  3.84
# 2  3  "3   0.23     ""Good""  ""E""    vS1""   56.9   65.0    327  4.05  4.07
# 3  4  "4   0.29  ""Premium""  ""I""    vS2""   62.4   58.0    334  4.20  4.23
# 4  5  "5   0.31     ""Good""  ""J""  ""SI2""   63.3   58.0    335  4.34  4.35
#
#        z
# 0  2.43"
# 1  2.31"
# 2  2.31"
# 3  2.63"
# 4  2.75"

# %%
df = df.drop(columns=['nr', "#"])

# %%
df.head()
# Out:
#    carat          cut  color  clarity  depth  table  price     x     y      z
# 0   0.23    ""Ideal""  ""E""  ""SI2""   61.5   55.0    326  3.95  3.98  2.43"
# 1   0.21  ""Premium""  ""E""  ""SI1""   59.8   61.0    326  3.89  3.84  2.31"
# 2   0.23     ""Good""  ""E""    vS1""   56.9   65.0    327  4.05  4.07  2.31"
# 3   0.29  ""Premium""  ""I""    vS2""   62.4   58.0    334  4.20  4.23  2.63"
# 4   0.31     ""Good""  ""J""  ""SI2""   63.3   58.0    335  4.34  4.35  2.75"

# %%
df.head(30)
# Out:
#     carat          cut  color  clarity  depth  table  price     x     y      z
# 0    0.23    ""Ideal""  ""E""  ""SI2""   61.5   55.0    326  3.95  3.98  2.43"
# 1    0.21  ""Premium""  ""E""  ""SI1""   59.8   61.0    326  3.89  3.84  2.31"
# 2    0.23     ""Good""  ""E""    vS1""   56.9   65.0    327  4.05  4.07  2.31"
# 3    0.29  ""Premium""  ""I""    vS2""   62.4   58.0    334  4.20  4.23  2.63"
# 4    0.31     ""Good""  ""J""  ""SI2""   63.3   58.0    335  4.34  4.35  2.75"
# 5    0.24  very Good""  ""J""   vVS2""   62.8   57.0    336  3.94  3.96  2.48"
# 6    0.24  very Good""  ""I""   vVS1""   62.3   57.0    336  3.95  3.98  2.47"
# 7    0.26  very Good""  ""H""  ""SI1""   61.9   55.0    337  4.07  4.11  2.53"
# 8    0.22     ""Fair""  ""E""    vS2""   65.1   61.0    337  3.87  3.78  2.49"
# 9    0.23  very Good""  ""H""    vS1""   59.4   61.0    338  4.00  4.05  2.39"
# 10   0.30     ""Good""  ""J""  ""SI1""   64.0   55.0    339  4.25  4.28  2.73"
# ...

# %%
df['cut'] = df['cut'].str.replace('""', '')

# %%
df.head()
# Out:
#    carat      cut  color  clarity  depth  table  price     x     y      z
# 0   0.23    Ideal  ""E""  ""SI2""   61.5   55.0    326  3.95  3.98  2.43"
# 1   0.21  Premium  ""E""  ""SI1""   59.8   61.0    326  3.89  3.84  2.31"
# 2   0.23     Good  ""E""    vS1""   56.9   65.0    327  4.05  4.07  2.31"
# 3   0.29  Premium  ""I""    vS2""   62.4   58.0    334  4.20  4.23  2.63"
# 4   0.31     Good  ""J""  ""SI2""   63.3   58.0    335  4.34  4.35  2.75"

# %%
df['color'] = df['color'].str.replace('""', '')

# %%
df.head()
# Out:
#    carat      cut color  clarity  depth  table  price     x     y      z
# 0   0.23    Ideal     E  ""SI2""   61.5   55.0    326  3.95  3.98  2.43"
# 1   0.21  Premium     E  ""SI1""   59.8   61.0    326  3.89  3.84  2.31"
# 2   0.23     Good     E    vS1""   56.9   65.0    327  4.05  4.07  2.31"
# 3   0.29  Premium     I    vS2""   62.4   58.0    334  4.20  4.23  2.63"
# 4   0.31     Good     J  ""SI2""   63.3   58.0    335  4.34  4.35  2.75"

# %%
df['clarity'] = df['clarity'].str.replace('""', '')

# %%
df.head(15)
# Out:
#     carat        cut color clarity  depth  table  price     x     y      z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43"
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31"
# 2    0.23       Good     E     vS1   56.9   65.0    327  4.05  4.07  2.31"
# 3    0.29    Premium     I     vS2   62.4   58.0    334  4.20  4.23  2.63"
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75"
# 5    0.24  very Good     J    vVS2   62.8   57.0    336  3.94  3.96  2.48"
# 6    0.24  very Good     I    vVS1   62.3   57.0    336  3.95  3.98  2.47"
# 7    0.26  very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53"
# 8    0.22       Fair     E     vS2   65.1   61.0    337  3.87  3.78  2.49"
# 9    0.23  very Good     H     vS1   59.4   61.0    338  4.00  4.05  2.39"
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73"
# ...

# %%
df['z'] = df['z'].str.replace('"', '')

# %%
df.head(15)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     vS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     vS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  very Good     J    vVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  very Good     I    vVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     vS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  very Good     H     vS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     vS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
df['clarity'] = df['clarity'].str.upper()
df['cut'] = df['cut'].str.upper()

# %%
df.head(30)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      IDEAL     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    PREMIUM     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       GOOD     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    PREMIUM     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       GOOD     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  VERY GOOD     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  VERY GOOD     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  VERY GOOD     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       FAIR     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  VERY GOOD     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       GOOD     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      IDEAL     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
df.isnull().sum()
# Out:
# carat         0
# cut           0
# color      9542
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df.eq(0).sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          8
# y          7
# z          0
# dtype: int64

# %%
df.loc[(df['x']==0) | (df['y']==0)]
# Out:
#        carat        cut color clarity  depth  table  price    x     y  z
# 11182   1.07      IDEAL   NaN     SI2   61.6   56.0   4954  0.0  6.62  0
# 11963   1.00  VERY GOOD     H     VS2   63.3   53.0   5139  0.0  0.00  0
# 15951   1.14       FAIR     G     VS1   57.5   67.0   6381  0.0  0.00  0
# 24520   1.56      IDEAL     G     VS2   62.2   54.0  12800  0.0  0.00  0
# 26243   1.20    PREMIUM     D    VVS1   62.1   59.0  15686  0.0  0.00  0
# 27429   2.25    PREMIUM     H     SI2   62.8   59.0  18034  0.0  0.00  0
# 49556   0.71       GOOD   NaN     SI2   64.1   60.0   2130  0.0  0.00  0
# 49557   0.71       GOOD   NaN     SI2   64.1   60.0   2130  0.0  0.00  0

# %%
# Sprawdzenie czy wartości 0 wystepują w kolumnach x,y,x
df.loc[(df['x']==0) | (df['y']==0) | (df['z']==0)]
# Out:
#        carat        cut color clarity  depth  table  price    x     y  z
# 11182   1.07      IDEAL   NaN     SI2   61.6   56.0   4954  0.0  6.62  0
# 11963   1.00  VERY GOOD     H     VS2   63.3   53.0   5139  0.0  0.00  0
# 15951   1.14       FAIR     G     VS1   57.5   67.0   6381  0.0  0.00  0
# 24520   1.56      IDEAL     G     VS2   62.2   54.0  12800  0.0  0.00  0
# 26243   1.20    PREMIUM     D    VVS1   62.1   59.0  15686  0.0  0.00  0
# 27429   2.25    PREMIUM     H     SI2   62.8   59.0  18034  0.0  0.00  0
# 49556   0.71       GOOD   NaN     SI2   64.1   60.0   2130  0.0  0.00  0
# 49557   0.71       GOOD   NaN     SI2   64.1   60.0   2130  0.0  0.00  0

# %%
len(df[(df['x']==0) | (df['y']==0) | (df['z']==0)])
# Out:
# 8

# %%
# Usunięcie wartości 0 z kolumn x,y,z
df = df.loc[(df['x'] != 0) & (df['y'] != 0) & (df['z'] != 0)]

# %%
# Spradzenie czy wartości 0 wystepują w kolumnach x,y,x
df.loc[(df['x']==0) | (df['y']==0) | (df['z']==0)]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
len(df[(df['x']==0) | (df['y']==0) | (df['z']==0)])
# Out:
# 0

# %%
df.head(100)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      IDEAL     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    PREMIUM     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       GOOD     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    PREMIUM     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       GOOD     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..    ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 95   0.70       GOOD     E     VS2   57.5   58.0   2759  5.85  5.90  3.38
# 96   0.70       GOOD   NaN     VS1   59.4   62.0   2759  5.71  5.76   3.4
# 97   0.96       FAIR   NaN     SI2   66.3   62.0   2759  6.27  5.95  4.07
# 98   0.73  VERY GOOD     E     SI1   61.6   59.0   2760  5.77  5.78  3.56
# 99   0.80    PREMIUM     H     SI1   61.5   58.0   2760  5.97  5.93  3.66
#
# [100 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# carat         0
# cut           0
# color      9539
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53932 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53932 non-null  float64
#  1   cut      53932 non-null  object
#  2   color    44393 non-null  object
#  3   clarity  53932 non-null  object
#  4   depth    53932 non-null  float64
#  5   table    53932 non-null  float64
#  6   price    53932 non-null  int64
#  7   x        53932 non-null  float64
#  8   y        53932 non-null  float64
#  9   z        53932 non-null  object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
# Usunięcie wartości isNull
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44393 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    44393 non-null  float64
#  1   cut      44393 non-null  object
#  2   color    44393 non-null  object
#  3   clarity  44393 non-null  object
#  4   depth    44393 non-null  float64
#  5   table    44393 non-null  float64
#  6   price    44393 non-null  int64
#  7   x        44393 non-null  float64
#  8   y        44393 non-null  float64
#  9   z        44393 non-null  object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 3.7+ MB

# %%
df.head(30)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      IDEAL     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    PREMIUM     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       GOOD     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    PREMIUM     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       GOOD     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  VERY GOOD     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  VERY GOOD     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  VERY GOOD     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       FAIR     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  VERY GOOD     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       GOOD     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      IDEAL     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
df.head(100)
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 0     0.23    IDEAL     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  PREMIUM     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     GOOD     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  PREMIUM     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     GOOD     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 105   0.75    IDEAL     G     SI1   62.2   55.0   2760  5.87  5.80  3.63
# 106   0.80  PREMIUM     G     SI1   63.0   59.0   2760  5.90  5.81  3.69
# 107   0.74    IDEAL     I    VVS2   62.3   55.0   2761  5.77  5.81  3.61
# 109   0.59    IDEAL     E    VVS2   62.0   55.0   2761  5.38  5.43  3.35
# 111   0.74    IDEAL     E     SI2   62.2   56.0   2761  5.80  5.84  3.62
#
# [100 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44393 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    44393 non-null  float64
#  1   cut      44393 non-null  object
#  2   color    44393 non-null  object
#  3   clarity  44393 non-null  object
#  4   depth    44393 non-null  float64
#  5   table    44393 non-null  float64
#  6   price    44393 non-null  int64
#  7   x        44393 non-null  float64
#  8   y        44393 non-null  float64
#  9   z        44393 non-null  object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 3.7+ MB

# %%
df.head(30)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      IDEAL     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    PREMIUM     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       GOOD     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    PREMIUM     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       GOOD     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  VERY GOOD     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  VERY GOOD     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  VERY GOOD     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       FAIR     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  VERY GOOD     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       GOOD     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      IDEAL     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
# Zresetowanie indexów
df.reset_index(drop=True, inplace=True)

# %%
df.head(30)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      IDEAL     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    PREMIUM     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       GOOD     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    PREMIUM     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       GOOD     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  VERY GOOD     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  VERY GOOD     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  VERY GOOD     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       FAIR     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  VERY GOOD     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       GOOD     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      IDEAL     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
#Zapisanie pliku .csv metodą ".to_csv"
