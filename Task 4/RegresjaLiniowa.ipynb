# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/BigDataGrupaDruga/BigDataDiamonds/refs/heads/main/Task%202/DataWithValues/DanezWartosciami.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           0   0.23    IDEAL     E     SI2   61.5   55.0    326  3.95  3.98
# 1           1   0.21  PREMIUM     E     SI1   59.8   61.0    326  3.89  3.84
# 2           2   0.23     GOOD     E     VS1   56.9   65.0    327  4.05  4.07
# 3           3   0.29  PREMIUM     I     VS2   62.4   58.0    334  4.20  4.23
# 4           4   0.31     GOOD     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z  cut value  color value  clarity value
# 0  2.43          5            6              2
# 1  2.31          4            6              3
# 2  2.31          2            6              5
# 3  2.63          4            2              4
# 4  2.75          2            1              2

# %%
df.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 44388       44388   0.72      IDEAL     D     SI1   60.8   57.0   2757  5.75
# 44389       44389   0.72       GOOD     D     SI1   63.1   55.0   2757  5.69
# 44390       44390   0.70  VERY GOOD     D     SI1   62.8   60.0   2757  5.66
# 44391       44391   0.86    PREMIUM     H     SI2   61.0   58.0   2757  6.15
# 44392       44392   0.75      IDEAL     D     SI2   62.2   55.0   2757  5.83
#
#           y     z  cut value  color value  clarity value
# 44388  5.76  3.50          5            7              3
# 44389  5.75  3.61          2            7              3
# 44390  5.68  3.56          3            7              3
# 44391  6.12  3.74          4            3              2
# 44392  5.87  3.64          5            7              2

# %%
df.drop(columns=['Unnamed: 0', 'cut', 'color', 'clarity'], inplace=True)

# %%
df.head()
# Out:
#    carat  depth  table  price     x     y     z  cut value  color value  \
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43          5            6
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31          4            6
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31          2            6
# 3   0.29   62.4   58.0    334  4.20  4.23  2.63          4            2
# 4   0.31   63.3   58.0    335  4.34  4.35  2.75          2            1
#
#    clarity value
# 0              2
# 1              3
# 2              5
# 3              4
# 4              2

# %%
X = df.drop(['price'], axis=1 , inplace = False)
X.head()
# Out:
#    carat  depth  table     x     y     z  cut value  color value  \
# 0   0.23   61.5   55.0  3.95  3.98  2.43          5            6
# 1   0.21   59.8   61.0  3.89  3.84  2.31          4            6
# 2   0.23   56.9   65.0  4.05  4.07  2.31          2            6
# 3   0.29   62.4   58.0  4.20  4.23  2.63          4            2
# 4   0.31   63.3   58.0  4.34  4.35  2.75          2            1
#
#    clarity value
# 0              2
# 1              3
# 2              5
# 3              4
# 4              2

# %%
Y = df['price']
Y.head()
# Out:
# 0    326
# 1    326
# 2    327
# 3    334
# 4    335
# Name: price, dtype: int64

# %%
#import modułu Scikit-learn do treningu danych
from sklearn.model_selection import train_test_split

#podział danych na treningowe i testowe
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=1/3, random_state=44)

# %%
#wybór regresji liniowej jako modelu do treningu, czyli wskaźnika dopasowania cech diamentów(X) do ceny(Y)
from sklearn.linear_model import LinearRegression

# %%
#przeprowadzenie treningu metodą regresji liniopwej
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
print('Wynik treningu regresji liniowej wynosi : ' , model.score(X_train, Y_train))
print('Wynik testów regresji liniowej wynosi: ' , model.score(X_test, Y_test))
# Out:
# Wynik treningu regresji liniowej wynosi :  0.9102084735169927
# Wynik testów regresji liniowej wynosi:  0.9088980431231123

# %%
#Powyższy trening (czyli dopasowanie) wykonane metodą regresji liniowej daje obiecujące rezultaty.
#Trening wskazał, że przy korzystając z regresji liniowej istnieje 91,02% relacja między cechami diamentów a ich ceną.
#Ponadto wyniki testów pokrywają się z rezultatami treningowymi wzkazując na 90.89% zależność dla danych testowych(w ujęciu cechy diamentów - cena diamentów).
