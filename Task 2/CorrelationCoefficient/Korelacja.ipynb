# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Link do pliku
url = 'https://raw.githubusercontent.com/BigDataGrupaDruga/BigDataDiamonds/refs/heads/main/Task%202/DataWithValues/DanezWartosciami.csv'
df = pd.read_csv(url)

# %%
df.head(15)
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0            0   0.23      IDEAL     E     SI2   61.5   55.0    326  3.95
# 1            1   0.21    PREMIUM     E     SI1   59.8   61.0    326  3.89
# 2            2   0.23       GOOD     E     VS1   56.9   65.0    327  4.05
# 3            3   0.29    PREMIUM     I     VS2   62.4   58.0    334  4.20
# 4            4   0.31       GOOD     J     SI2   63.3   58.0    335  4.34
# 5            5   0.24  VERY GOOD     J    VVS2   62.8   57.0    336  3.94
# 6            6   0.24  VERY GOOD     I    VVS1   62.3   57.0    336  3.95
# 7            7   0.26  VERY GOOD     H     SI1   61.9   55.0    337  4.07
# 8            8   0.22       FAIR     E     VS2   65.1   61.0    337  3.87
# 9            9   0.23  VERY GOOD     H     VS1   59.4   61.0    338  4.00
# 10          10   0.30       GOOD     J     SI1   64.0   55.0    339  4.25
# 11          11   0.23      IDEAL     J     VS1   62.8   56.0    340  3.93
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  44393.000000  44393.000000  44393.000000  44393.000000  44393.000000
# mean   22196.000000      0.811066     61.761208     57.462161   3976.624941
# std    12815.299587      0.487835      1.431218      2.227479   4029.721525
# min        0.000000      0.200000     43.000000     43.000000    326.000000
# 25%    11098.000000      0.400000     61.100000     56.000000    943.000000
# 50%    22196.000000      0.710000     61.900000     57.000000   2433.000000
# 75%    33294.000000      1.060000     62.500000     59.000000   5424.000000
# max    44392.000000      5.010000     79.000000     76.000000  18823.000000
#
#                   x             y             z     cut value   color value  \
# count  44393.000000  44393.000000  44393.000000  44393.000000  44393.000000
# mean       5.756778      5.759905      3.555100      3.908139      4.278107
# ...

# %%
df_corr = df.drop(columns=['Unnamed: 0', 'cut', 'color', 'clarity'])
corr = df_corr.corr()

plt.figure(figsize = (12,12))
sns.heatmap(data=corr, square=True , annot=True, cbar=True)
# Out:
# <Axes: >
